# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
train_test = pd.read_csv('../Bejing Data/Train_test.csv')
train_test
# Out:
#                       date  pollution  dew  temp   press wnd_dir  wnd_spd  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25
# ...                    ...        ...  ...   ...     ...     ...      ...
# 35034  2013-12-31 18:00:00       15.0  -19   8.0  1013.0      NW   109.95
# 35035  2013-12-31 19:00:00       22.0  -19   7.0  1013.0      NW   114.87
# 35036  2013-12-31 20:00:00       18.0  -21   7.0  1014.0      NW   119.79
# 35037  2013-12-31 21:00:00       23.0  -21   7.0  1014.0      NW   125.60
# 35038  2013-12-31 22:00:00       20.0  -21   6.0  1014.0      NW   130.52
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# 3         1     0
# 4         2     0
# ...     ...   ...
# 35034     0     0
# 35035     0     0
# 35036     0     0
# 35037     0     0
# 35038     0     0
#
# [35039 rows x 9 columns]

# %%
x=train_test.drop("pollution",axis=1)
y=train_test["pollution"]

# %%
train_test["wnd_dir"]=pd.factorize( train_test["wnd_dir"])[0]

# %%
train_test=train_test.drop("date",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12464/3782428360.py in <module>
# ----> 1 train_test=train_test.drop("date",axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['date'] not found in axis"

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=22)

# %%
mod_ar2 = sm.tsa.SARIMAX(y_train,x_train, order=(2,0,0))

# Fit the model via maximum likelihood
res_ar2 = mod_ar2.fit()
# Note that res_ar2 is an instance of the SARIMAXResults class

# Show the summary of results
print(res_ar2.summary());
# Out:
# C:\Users\Ice\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Ice\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:              pollution   No. Observations:                28031
# Model:               SARIMAX(2, 0, 0)   Log Likelihood             -162898.053
# Date:                Wed, 09 Feb 2022   AIC                         325816.105
# Time:                        08:58:41   BIC                         325898.516
# Sample:                             0   HQIC                        325842.633
#                               - 28031
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dew            4.3419      0.083     52.381      0.000       4.179       4.504
# temp          -5.0398      0.088    -57.489      0.000      -5.212      -4.868
# press          0.1662      0.001    148.754      0.000       0.164       0.168
# wnd_dir      -12.6138      0.494    -25.509      0.000     -13.583     -11.645
# wnd_spd       -0.2179      0.016    -13.637      0.000      -0.249      -0.187
# snow          -2.0691      0.621     -3.333      0.001      -3.286      -0.852
# rain          -5.7427      0.447    -12.854      0.000      -6.618      -4.867
# ar.L1          0.0035      0.006      0.585      0.558      -0.008       0.015
# ar.L2         -0.0016      0.006     -0.266      0.790      -0.014       0.010
# sigma2      6534.7647     35.821    182.431      0.000    6464.558    6604.972
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             62693.45
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.96   Skew:                             1.72
# Prob(H) (two-sided):                  0.04   Kurtosis:                         9.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
mod_sarimax = sm.tsa.SARIMAX(y_train,x_train, order=(1,1,1),
                             seasonal_order=(0,1,1,4))
res_sarimax = mod_sarimax.fit()

# Show the summary of results
print(res_sarimax.summary())
# Out:
# C:\Users\Ice\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Ice\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:578: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
# C:\Users\Ice\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                         pollution   No. Observations:                28031
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 4)   Log Likelihood             -163871.042
# Date:                           Wed, 09 Feb 2022   AIC                         327764.085
# Time:                                   09:02:51   BIC                         327854.734
# Sample:                                        0   HQIC                        327793.265
#                                          - 28031
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# dew            3.9622      0.125     31.701      0.000       3.717       4.207
# temp          -5.8580      0.144    -40.761      0.000      -6.140      -5.576
# press         -1.7212      0.136    -12.688      0.000      -1.987      -1.455
# wnd_dir      -12.6892      0.768    -16.529      0.000     -14.194     -11.185
# wnd_spd       -0.2184      0.024     -8.970      0.000      -0.266      -0.171
# snow          -1.2794      0.935     -1.368      0.171      -3.113       0.554
# rain          -5.9206      0.681     -8.688      0.000      -7.256      -4.585
# ar.L1         -0.0019      0.010     -0.204      0.838      -0.021       0.017
# ma.L1         -0.9999      0.000  -2069.592      0.000      -1.001      -0.999
# ma.S.L4       -0.9997      0.001  -1720.824      0.000      -1.001      -0.999
# sigma2      1.008e+04     75.995    132.641      0.000    9931.113    1.02e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.35   Jarque-Bera (JB):             63547.18
# Prob(Q):                              0.55   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.96   Skew:                             1.72
# Prob(H) (two-sided):                  0.08   Kurtosis:                         9.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error
rms = sqrt(mean_squared_error(y_test,forecast))
print("RMSE: ", rms)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12464/3151036707.py in <module>
#       1 from math import sqrt
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 rms = sqrt(mean_squared_error(y_test,forecast))
#       4 print("RMSE: ", rms)
#
# NameError: name 'forecast' is not defined
